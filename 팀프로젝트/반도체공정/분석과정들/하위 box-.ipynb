# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %%
df_low = pd.read_csv("C:/Users/USER/Desktop/반도체 공정/데이터/하위6개_new.csv",encoding='euc-kr')
df_low
# Out:
#     Unnamed: 0  Unnamed: 0.1 type    Temp_OXid    ppm  Pressure  Oxid_time  \
# 0            0           161  dry  1171.352233  29.45     0.211        108
# 1            1           263  dry   862.011276  29.07     0.195         56
# 2            2           368  dry   871.010621  21.94     0.220        227
# 3            3           461  dry   873.686720  22.17     0.219         27
# 4            4           464  dry   888.519511  32.80     0.218         32
# ..         ...           ...  ...          ...    ...       ...        ...
# 83          83           905  dry   887.766797  32.88     0.227         32
# 84          84           908  dry   878.057509  35.63     0.223         32
# 85          85          1091  wet  1087.933217  22.76     0.209        109
# 86          86          1094  wet  1119.269073  34.06     0.213        147
# 87          87          1097  dry   965.744223  30.27     0.214        144
#
# ...

# %%
df_high = pd.read_csv("C:/Users/USER/Desktop/반도체 공정/데이터/상위6개_new.csv",encoding='euc-kr')
df_high
# Out:
#     Unnamed: 0  Unnamed: 0.1 type    Temp_OXid    ppm  Pressure  Oxid_time  \
# 0            0           217  dry  1209.088990  30.34     0.203         50
# 1            1           220  dry  1065.177048  35.89     0.196        184
# 2            2           223  wet   994.895749  33.83     0.224         69
# 3            3          1000  dry   886.980512  22.48     0.222         23
# 4            4          1003  dry   884.601447  22.48     0.223         25
# ..         ...           ...  ...          ...    ...       ...        ...
# 86          86          1229  wet  1295.414674  45.35     0.226         33
# 87          87          1232  wet  1277.436051  45.47     0.224         31
# 88          88          1415  dry   982.069228  34.58     0.215         28
# 89          89          1418  dry  1234.788085  38.02     0.200         29
# 90          90          1421  dry  1077.344874  49.91     0.202         30
#
# ...

# %%
df_high["quality"]="Good"
df_low["quality"]="Bad"

# %%
df_low
# Out:
#     Unnamed: 0  Unnamed: 0.1 type    Temp_OXid    ppm  Pressure  Oxid_time  \
# 0            0           161  dry  1171.352233  29.45     0.211        108
# 1            1           263  dry   862.011276  29.07     0.195         56
# 2            2           368  dry   871.010621  21.94     0.220        227
# 3            3           461  dry   873.686720  22.17     0.219         27
# 4            4           464  dry   888.519511  32.80     0.218         32
# ..         ...           ...  ...          ...    ...       ...        ...
# 83          83           905  dry   887.766797  32.88     0.227         32
# 84          84           908  dry   878.057509  35.63     0.223         32
# 85          85          1091  wet  1087.933217  22.76     0.209        109
# 86          86          1094  wet  1119.269073  34.06     0.213        147
# 87          87          1097  dry   965.744223  30.27     0.214        144
#
# ...

# %%
result1 = pd.concat([df_high,df_low])

# %%
result1
# Out:
#     Unnamed: 0  Unnamed: 0.1 type    Temp_OXid    ppm  Pressure  Oxid_time  \
# 0            0           217  dry  1209.088990  30.34     0.203         50
# 1            1           220  dry  1065.177048  35.89     0.196        184
# 2            2           223  wet   994.895749  33.83     0.224         69
# 3            3          1000  dry   886.980512  22.48     0.222         23
# 4            4          1003  dry   884.601447  22.48     0.223         25
# ..         ...           ...  ...          ...    ...       ...        ...
# 83          83           905  dry   887.766797  32.88     0.227         32
# 84          84           908  dry   878.057509  35.63     0.223         32
# 85          85          1091  wet  1087.933217  22.76     0.209        109
# 86          86          1094  wet  1119.269073  34.06     0.213        147
# 87          87          1097  dry   965.744223  30.27     0.214        144
#
# ...

# %%
result1.boxplot(column="resist_target", by=["quality"],figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'resist_target'}, xlabel='[quality]'>

# %%
result1.groupby("quality")["resist_target"].describe()
# Out:
#          count      mean       std      min      25%      50%       75%  \
# quality
# Bad       88.0  1.296399  0.465651  0.43355  0.94868  1.22609  1.662812
# Good      91.0  1.223816  0.366837  0.49182  0.95798  1.16379  1.489120
#
#              max
# quality
# Bad      2.34062
# Good     2.19916

# %%
low_resist = df_low['resist_target']
high_resist = df_high['resist_target']

# %%
from scipy.stats import mannwhitneyu

print(mannwhitneyu(low_resist,high_resist))
# Out:
# MannwhitneyuResult(statistic=3710.5, pvalue=0.19887958523375915)

# %%
result1.boxplot(column="N2_HMDS", by=["quality"],figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'N2_HMDS'}, xlabel='[quality]'>

# %%
result1.groupby("quality")["N2_HMDS"].describe()
# Out:
#          count       mean       std     min     25%      50%       75%     max
# quality
# Bad       88.0  15.982216  2.214431  11.048  14.606  16.1055  17.20675  20.701
# Good      91.0  15.713659  2.302484  10.470  14.493  16.0900  17.01400  20.149

# %%
low= df_low['N2_HMDS']
high = df_high['N2_HMDS']
print(mannwhitneyu(low,high))
# Out:
# MannwhitneyuResult(statistic=3771.5, pvalue=0.2516051795462515)

# %%
result1.boxplot(column="pressure_HMDS", by=["quality"],figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'pressure_HMDS'}, xlabel='[quality]'>

# %%
result1.groupby("quality")["pressure_HMDS"].describe()
# Out:
#          count       mean       std     min      25%      50%       75%  \
# quality
# Bad       88.0  15.015534  0.076006  14.838  14.9655  15.0095  15.06125
# Good      91.0  15.002000  0.078832  14.807  14.9540  15.0050  15.05100
#
#             max
# quality
# Bad      15.281
# Good     15.207

# %%
low= df_low['pressure_HMDS']
high = df_high['pressure_HMDS']
print(mannwhitneyu(low,high))
# Out:
# MannwhitneyuResult(statistic=3638.0, pvalue=0.1457980210649637)

# %%
result1.boxplot(column="temp_HMDS", by=["quality"],figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'temp_HMDS'}, xlabel='[quality]'>

# %%
result1.groupby("quality")["temp_HMDS"].describe()
# Out:
#          count      mean       std     min     25%     50%      75%     max
# quality
# Bad       88.0  19.99950  0.004034  19.990  19.997  19.999  20.0020  20.012
# Good      91.0  19.99978  0.003252  19.991  19.997  20.000  20.0025  20.008

# %%
low= df_low['temp_HMDS']
high = df_high['temp_HMDS']
print(mannwhitneyu(low,high))
# Out:
# MannwhitneyuResult(statistic=3746.0, pvalue=0.22762688722753183)

# %%
result1.boxplot(column="temp_HMDS_bake", by=["quality"],figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'temp_HMDS_bake'}, xlabel='[quality]'>

# %%
result1.groupby("quality")["temp_HMDS_bake"].describe()
# Out:
#          count        mean       std      min      25%       50%        75%  \
# quality
# Bad       88.0  200.542000  3.423287  193.932  197.925  200.2325  203.27025
# Good      91.0  200.103341  2.735517  192.937  198.317  199.9510  202.29700
#
#              max
# quality
# Bad      209.521
# Good     206.338

# %%
low= df_low['temp_HMDS_bake']
high = df_high['temp_HMDS_bake']
print(mannwhitneyu(low,high))
# Out:
# MannwhitneyuResult(statistic=3829.0, pvalue=0.30730847516319915)

# %%
result1.boxplot(column="time_HMDS_bake", by=["quality"],figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'time_HMDS_bake'}, xlabel='[quality]'>

# %%
result1.groupby("quality")["time_HMDS_bake"].describe()
# Out:
#          count       mean       std     min     25%   50%      75%     max
# quality
# Bad       88.0  90.000102  0.000858  89.998  89.999  90.0  90.0010  90.002
# Good      91.0  90.000033  0.000781  89.998  90.000  90.0  90.0005  90.002

# %%
low= df_low['time_HMDS_bake']
high = df_high['time_HMDS_bake']
print(mannwhitneyu(low,high))
# Out:
# MannwhitneyuResult(statistic=3765.0, pvalue=0.23089734224693798)

# %%
result1.boxplot(column="spin1", by=["quality"],figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'spin1'}, xlabel='[quality]'>

# %%
result1.groupby("quality")["spin1"].describe()
# Out:
#          count        mean       std      min        25%      50%        75%  \
# quality
# Bad       88.0  500.642534  3.139894  493.983  498.67025  501.188  502.94225
# Good      91.0  500.366835  2.964085  494.517  498.51600  500.125  502.42600
#
#              max
# quality
# Bad      506.204
# Good     507.932

# %%
low= df_low['spin1']
high = df_high['spin1']
print(mannwhitneyu(low,high))
# Out:
# MannwhitneyuResult(statistic=3708.5, pvalue=0.19732912856171098)

# %%
result1.boxplot(column="spin2", by=["quality"],figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'spin2'}, xlabel='[quality]'>

# %%
result1.groupby("quality")["spin2"].describe()
# Out:
#          count         mean        std       min         25%       50%  \
# quality
# Bad       88.0  4028.252432  53.562154  3879.656  3979.70225  4033.621
# Good      91.0  4014.546253  50.247847  3864.820  3975.03250  4013.975
#
#                 75%       max
# quality
# Bad      4068.98375  4129.907
# Good     4047.52450  4135.365

# %%
low= df_low['spin2']
high = df_high['spin2']
print(mannwhitneyu(low,high))
# Out:
# MannwhitneyuResult(statistic=3376.0, pvalue=0.035101865485314986)

# %%
result1.boxplot(column="spin3", by=["quality"],figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'spin3'}, xlabel='[quality]'>

# %%
result1.groupby("quality")["spin3"].describe()
# Out:
#          count         mean        std       min       25%        50%  \
# quality
# Bad       88.0  5012.284011  76.796209  4849.571  4946.999  5015.0105
# Good      91.0  5027.239824  58.412563  4900.431  4979.824  5026.7640
#
#                 75%       max
# quality
# Bad      5073.56275  5155.091
# Good     5071.38450  5158.447

# %%
low= df_low['spin3']
high = df_high['spin3']
print(mannwhitneyu(low,high))
# Out:
# MannwhitneyuResult(statistic=3553.0, pvalue=0.09682850848707564)

# %%
result1.boxplot(column="photoresist_bake", by=["quality"],figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'photoresist_bake'}, xlabel='[quality]'>

# %%
result1.groupby("quality")["photoresist_bake"].describe()
# Out:
#          count      mean       std    min     25%    50%     75%    max
# quality
# Bad       88.0  5.020375  0.073073  4.835  4.9635  5.017  5.0775  5.239
# Good      91.0  5.018022  0.066049  4.863  4.9710  5.013  5.0680  5.148

# %%
low= df_low['photoresist_bake']
high = df_high['photoresist_bake']
print(mannwhitneyu(low,high))
# Out:
# MannwhitneyuResult(statistic=3964.0, pvalue=0.4546292728847312)

# %%
result1.boxplot(column="temp_softbake", by=["quality"],figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'temp_softbake'}, xlabel='[quality]'>

# %%
result1.groupby("quality")["temp_softbake"].describe()
# Out:
#          count       mean       std     min       25%      50%       75%  \
# quality
# Bad       88.0  92.167227  1.380487  88.693  91.33175  92.1205  93.14525
# Good      91.0  91.793033  1.551682  86.498  90.99550  91.8050  92.93050
#
#             max
# quality
# Bad      95.838
# Good     95.280

# %%
low= df_low['temp_softbake']
high = df_high['temp_softbake']
print(mannwhitneyu(low,high))
# Out:
# MannwhitneyuResult(statistic=3422.0, pvalue=0.04669125630319352)

# %%
result1.boxplot(column="time_softbake", by=["quality"],figsize=(8,8))
# Out:
# <AxesSubplot:title={'center':'time_softbake'}, xlabel='[quality]'>

# %%
result1.groupby("quality")["time_softbake"].describe()
# Out:
#          count       mean       std     min     25%     50%     75%     max
# quality
# Bad       88.0  30.000045  0.005717  29.988  29.997  30.001  30.005  30.011
# Good      91.0  30.000813  0.005513  29.989  29.998  30.001  30.003  30.014

# %%
low= df_low['time_softbake']
high = df_high['time_softbake']
print(mannwhitneyu(low,high))
# Out:
# MannwhitneyuResult(statistic=3829.0, pvalue=0.3069559525810325)

# %%
df_soft = df[['resist_target','N2_HMDS','pressure_HMDS','temp_HMDS','temp_HMDS_bake','time_HMDS_bake','spin1','spin2','spin3','photoresist_bake','temp_softbake','time_softbake']]
df_soft
# Out:
#     resist_target  N2_HMDS  pressure_HMDS  temp_HMDS  temp_HMDS_bake  \
# 0         1.32730   15.965         14.968     19.996         200.435
# 1         1.00626   13.311         15.060     19.996         202.275
# 2         1.05465   16.326         15.055     20.003         199.396
# 3         0.99309   19.026         14.917     19.995         204.556
# 4         0.51565   18.771         15.140     20.001         206.204
# ..            ...      ...            ...        ...             ...
# 83        1.72027   16.922         14.988     20.002         197.980
# 84        0.94868   19.026         15.058     19.998         197.135
# 85        1.19101   11.453         15.005     20.004         193.932
# 86        2.34062   15.651         15.104     19.994         198.542
# 87        1.36377   15.542         14.997     19.997         201.087
#
#     time_HMDS_bake    spin1     spin2     spin3  photoresist_bake  \
# 0           90.000  501.817  4078.065  4942.679             5.037
# ...
